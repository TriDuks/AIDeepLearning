# %% [markdown]
# <a href="https://colab.research.google.com/github/TriDuks/AIDeepLearning/blob/main/MTCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mtcnn
# !pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 30.9 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN

# %%
from decorator import decorate
filename ='/content/drive/MyDrive/AI/Face/6.jpg'
pixels = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(pixels)
for face in faces:
  print(face)
# Out:
# ...
# 1/1 [==============================] - 0s 164ms/step
# {'box': [477, 148, 79, 97], 'confidence': 0.9999593496322632, 'keypoints': {'left_eye': (491, 188), 'right_eye': (522, 183), 'nose': (500, 204), 'mouth_left': (497, 225), 'mouth_right': (523, 220)}}
# {'box': [278, 100, 81, 107], 'confidence': 0.999933660030365, 'keypoints': {'left_eye': (294, 145), 'right_eye': (331, 143), 'nose': (308, 168), 'mouth_left': (300, 182), 'mouth_right': (332, 180)}}
# {'box': [76, 141, 109, 129], 'confidence': 0.9999235272407532, 'keypoints': {'left_eye': (102, 197), 'right_eye': (148, 183), 'nose': (131, 217), 'mouth_left': (120, 242), 'mouth_right': (158, 230)}}

# %%
from decorator import decorate
filename ='/content/drive/MyDrive/AI/Face/6.jpg'
pixels = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(pixels)
for face in faces:
  print(face)
filename ='/content/drive/MyDrive/AI/Face/6.jpg'
pixels = plt.imread(filename)
plt.imshow(pixels)
ax = plt.gca()
i=0
for face in faces:
  i = i+1
  x,y,width,height = face['box']
  rect = plt.Rectangle((x,y), width, height, fill = False, color = 'red')
  ax.add_patch(rect)
  for key,value in face['keypoints'].items():
    dot = plt.Circle(value, radius=2, color = 'blue')
    ax.add_patch(dot)
plt.show() 
print('Số người: ', i)
# Out:
# ...
# 1/1 [==============================] - 0s 175ms/step
# {'box': [477, 148, 79, 97], 'confidence': 0.9999593496322632, 'keypoints': {'left_eye': (491, 188), 'right_eye': (522, 183), 'nose': (500, 204), 'mouth_left': (497, 225), 'mouth_right': (523, 220)}}
# {'box': [278, 100, 81, 107], 'confidence': 0.999933660030365, 'keypoints': {'left_eye': (294, 145), 'right_eye': (331, 143), 'nose': (308, 168), 'mouth_left': (300, 182), 'mouth_right': (332, 180)}}
# {'box': [76, 141, 109, 129], 'confidence': 0.9999235272407532, 'keypoints': {'left_eye': (102, 197), 'right_eye': (148, 183), 'nose': (131, 217), 'mouth_left': (120, 242), 'mouth_right': (158, 230)}}
# Số người:  3

# %%
def draw_faces(filename, result_list):
  filename ='/content/drive/MyDrive/AI/Face/6.jpg'
  data = plt.imread(filename)
  for i in range(len(result_list)):
    x1,y1,width,height = result_list[i]['box']
    x2,y2 = x1 + width, y1 + height
    plt.subplot(1, len(result_list), i+1)
    plt.axis('off')
    plt.imshow(data[y1:y2,x1:x2])
  plt.show()

filename ='/content/drive/MyDrive/AI/Face/6.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
draw_faces(filename, faces)
# Out:
# ...
# 1/1 [==============================] - 0s 157ms/step

# %%
plt.savefig('/content/drive/MyDrive/AI/Face/6.jpg)
# Out:
#   File "<ipython-input-52-59bb6abd8cfb>", line 1
#     plt.savefig('/content/drive/MyDrive/AI/Face/6.jpg)
#                                                       ^
# SyntaxError: EOL while scanning string literal

# %%
from decorator import decorate
filename ='/content/drive/MyDrive/AI/Face/7.jpg'
pixels = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(pixels)
for face in faces:
  print(face)
filename ='/content/drive/MyDrive/AI/Face/7.jpg'
pixels = plt.imread(filename)
plt.imshow(pixels)
ax = plt.gca()
i=0
for face in faces:
  i = i+1
  x,y,width,height = face['box']
  rect = plt.Rectangle((x,y), width, height, fill = False, color = 'red')
  ax.add_patch(rect)
  for key,value in face['keypoints'].items():
    dot = plt.Circle(value, radius=2, color = 'blue')
    ax.add_patch(dot)
plt.show() 
print('Số người: ', i)

def draw_faces(filename, result_list):
  filename ='/content/drive/MyDrive/AI/Face/7.jpg'
  data = plt.imread(filename)
  for i in range(len(result_list)):
    x1,y1,width,height = result_list[i]['box']
    x2,y2 = x1 + width, y1 + height
    plt.subplot(1, len(result_list), i+1)
    plt.axis('off')
    plt.imshow(data[y1:y2,x1:x2])
  plt.show()

filename ='/content/drive/MyDrive/AI/Face/7.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
draw_faces(filename, faces)
# Out:
# ...
# 4/4 [==============================] - 0s 35ms/step
# {'box': [650, 313, 39, 51], 'confidence': 0.9999991059303284, 'keypoints': {'left_eye': (659, 332), 'right_eye': (677, 332), 'nose': (667, 343), 'mouth_left': (660, 352), 'mouth_right': (676, 351)}}
# {'box': [124, 103, 35, 47], 'confidence': 0.9999827742576599, 'keypoints': {'left_eye': (136, 120), 'right_eye': (151, 120), 'nose': (144, 129), 'mouth_left': (137, 140), 'mouth_right': (150, 140)}}
# {'box': [114, 301, 39, 51], 'confidence': 0.9999818801879883, 'keypoints': {'left_eye': (125, 321), 'right_eye': (142, 321), 'nose': (133, 331), 'mouth_left': (127, 342), 'mouth_right': (141, 341)}}
# {'box': [273, 309, 38, 46], 'confidence': 0.9999365210533142, 'keypoints': {'left_eye': (284, 328), 'right_eye': (302, 327), 'nose': (293, 336), 'mouth_left': (286, 346), 'mouth_right': (301, 345)}}
# ...
